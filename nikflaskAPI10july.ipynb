# %%
from dotenv import load_dotenv
import os

from langchain_community.document_loaders import PyPDFLoader

from langchain_text_splitters import RecursiveCharacterTextSplitter

from langchain_groq import ChatGroq
from langchain_community.embeddings import HuggingFaceEmbeddings

from langchain_community.vectorstores import FAISS
from langchain_community.document_loaders import TextLoader

# %%
from flask import Flask


app = Flask("mpertoapi")

from langchain_community.document_loaders import DirectoryLoader, TextLoader



mpetriodoc = DirectoryLoader(r"C:\Users\nikky\OneDrive\Documents\internship\chatbotdemo\nikmoraboutmpertio",
    glob="*.txt",
    loader_cls=TextLoader
)



mperito_documents = mpetriodoc.load()

print("Total files loaded:", len(mperito_documents))
print(mperito_documents)

# %%
load_dotenv()

api_key = os.getenv("GROQ_API_KEY")

print(api_key)

# %%
mperito_text_splitter  = RecursiveCharacterTextSplitter(

    chunk_size=500,

    chunk_overlap=100
)

mperito_chunks = mperito_text_splitter.split_documents(mperito_documents)
print(len(mperito_chunks))
mperito_chunks[0]

# %%
Mpertiofastemb = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# %%
vectorfastdb = FAISS.from_documents(

    documents=mperito_chunks,

    embedding=Mpertiofastemb
    
)

# %%
mperito_vector_database .save_local("vectorfasissfastapi")

# %%
mperito_vector_database  = FAISS.load_local(
    "vectorfasissfastapi",
    Mpertiofastemb,  
    allow_dangerous_deserialization=True
)

# %%
from langchain_groq import ChatGroq
import os

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    groq_api_key=os.getenv("GROQ_API_KEY"),
    
    temperature=0
)

# %%
retrieved_documents = mperito_vector_db.similarity_search(
    user_query,
    k=4
)

retrieved_context = "\n\n".join(
    doc.page_content for doc in retrieved_documents
)
